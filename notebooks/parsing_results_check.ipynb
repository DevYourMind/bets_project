# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data_folder = '../data/'
df_events = pd.read_pickle(data_folder+'1x/events/2023.06.1.pkl')

# %%
df_tables = pd.read_pickle('D:/BettingProject/bets_project/data/1x/tables/2023.06.1/0.pkl')

# %%
df_events
# Out:
#                   date                                              event  \
# 0     01.06.2023 12:10                         Теннис : ATP. Ролан Гаррос
# 1     01.06.2023 12:10                         Теннис : ATP. Ролан Гаррос
# 2     01.06.2023 13:00                         Теннис : ATP. Ролан Гаррос
# 3     01.06.2023 13:50                         Теннис : ATP. Ролан Гаррос
# 4     01.06.2023 14:10                         Теннис : ATP. Ролан Гаррос
# ...                ...                                                ...
# 1513  01.06.2023 11:50  Теннис : Теннис. Турнир ITF. Испания. Ла-Нусия...
# 1514  01.06.2023 12:15  Теннис : Теннис. Турнир ITF. Испания. Ла-Нусия...
# 1515  01.06.2023 13:15  Теннис : Теннис. Турнир ITF. Испания. Ла-Нусия...
# 1516  01.06.2023 13:35  Теннис : Теннис. Турнир ITF. Испания. Ла-Нусия...
# 1517  01.06.2023 13:59  Теннис : Теннис. Турнир ITF. Испания. Ла-Нусия...
#
#                                        players  \
# ...

# %%
df_temp = pd.read_pickle(data_folder+'1x/events/2023.05.31.pkl').copy()
