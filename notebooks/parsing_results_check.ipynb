# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data_folder = '../data/'
df_events = pd.read_pickle(data_folder+'1x/events/2023.06.23.pkl')

# %%
df_tables = pd.read_pickle('C:/projects/betting/bets_project/data/1x/tables/2023.06.23/0.pkl')

# %%
df_tables
# Out:
#    Дата-время скана линии    П1    П2 1Х 2Х Х 12    ТМ ТМ бол ТМ мен  ...  \
# 0           22 июн 22:20   2,65  1,48             22,5   1,83   1,97  ...
# 1           22 июн 22:30   2,83  1,43             22,5   1,83   1,97  ...
# 2           22 июн 22:40      3  1,39             22,5   1,83   1,97  ...
# 3           22 июн 23:00   3,05  1,38             22,5   1,85   1,95  ...
# 4           23 июн 00:00   3,15  1,36             22,5   1,85   1,95  ...
# 5           23 июн 00:50   3,14  1,36             22,5   1,83   1,97  ...
# 6           23 июн 04:10      3  1,39             22,5   1,82   1,99  ...
# 7           23 июн 05:30   3,32  1,33             22,5   1,84   1,96  ...
# 8           23 июн 05:40   3,32  1,33             22,5   1,86   1,94  ...
# 9           23 июн 06:50    3,4  1,32             22,5   1,86   1,94  ...
# 10          23 июн 07:10   3,26  1,34             22,5   1,85   1,95  ...
# 11          23 июн 07:40   3,32  1,33             22,5   1,85   1,95  ...
# ...

# %%
df_events
# Out:
#                   date                                              event  \
# 0     23.06.2023 13:00                                Теннис : ATP. Галле
# 1     23.06.2023 14:30                                Теннис : ATP. Галле
# 2     23.06.2023 17:15                                Теннис : ATP. Галле
# 3     23.06.2023 19:15                                Теннис : ATP. Галле
# 4     23.06.2023 14:05                          Теннис : ATP. Галле. Пары
# ...                ...                                                ...
# 1273  23.06.2023 19:15  Теннис : Теннис. Турнир ITF. Доминиканская Рес...
# 1274  23.06.2023 16:30  Теннис : Теннис. Турнир ITF. Доминиканская Рес...
# 1275  23.06.2023 16:30  Теннис : Теннис. Турнир ITF. Доминиканская Рес...
# 1276  23.06.2023 16:30  Теннис : Теннис. Турнир ITF. Доминиканская Рес...
# 1277  23.06.2023 18:30  Теннис : Теннис. Турнир ITF. Доминиканская Рес...
#
#                                       players                         winner  \
# ...
